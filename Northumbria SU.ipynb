# %%
#import os lib for working directory
import os

# %%
#checking wd
os.getcwd()
# Out:
# 'c:\\Users\\ikech\\Downloads\\New folder'

# %%
#import lib(s)
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#import dataset
data = pd.read_csv("northumbria.csv")

# %%
# view first five rows
data.head()
# Out:
#                    Award Level                                     Dept  \
# 0  Engineering and Environment  Mechanical and Construction Engineering
# 1             Business and Law        Marketing, Operations and Systems
# 2             Business and Law        Marketing, Operations and Systems
# 3             Business and Law        Marketing, Operations and Systems
# 4             Business and Law        Marketing, Operations and Systems
#
#       Fee Status Level of Study       Campus  \
# 0  International              7  City Campus
# 1  International              7  City Campus
# 2  International              7  City Campus
# 3  International              7  City Campus
# 4  International              7  City Campus
#
#   I know where to look for support in the university if I am struggling financially   \
# 0                                           Neutral
# 1                                              Agree
# 2                                     Strongly Agree
# ...

# %%
# view last five rows
data.tail()
# Out:
#                      Award Level                                       Dept  \
# 506  Engineering and Environment          Computer and Information Sciences
# 507             Business and Law          Marketing, Operations and Systems
# 508             Business and Law  Entrepreneurship, Innovation and Strategy
# 509             Business and Law          Marketing, Operations and Systems
# 510          Central Departments                         QA Pathway College
#
#         Fee Status Level of Study         Campus  \
# 506  International              7  London Campus
# 507  International              7  London Campus
# 508  International              7  London Campus
# 509  International              7  London Campus
# 510  International              4  London Campus
#
#     I know where to look for support in the university if I am struggling financially   \
# 506                                           Disagree
# 507                                           Disagree
# ...

# %%
# show no of rows and columns
data.shape
# Out:
# (511, 13)

# %%
# show columns in dataset
data.columns
# Out:
# Index(['Award Level', 'Dept', 'Fee Status', 'Level of Study', 'Campus',
#        'I know where to look for support in the university if I am struggling financially ',
#        'I am confident that I can create a personal monthly budget',
#        'My maintenance loan covers all my rent and bills',
#        'I have/need a part time job to enable me to afford university',
#        'I have had to increase my hours at work to cover the higher cost of living',
#        'How do you think students are most affected by the cost of living?',
#        'What have you found difficult about settling in at university and cost of living?',
#        'What can the University and the Students’ Union do to help?'],
#       dtype='object')

# %%
# check for null rows
data.isnull().sum()
# Out:
# Award Level                                                                            0
# Dept                                                                                   0
# Fee Status                                                                             0
# Level of Study                                                                         0
# Campus                                                                                 0
# I know where to look for support in the university if I am struggling financially      0
# I am confident that I can create a personal monthly budget                             0
# My maintenance loan covers all my rent and bills                                       0
# I have/need a part time job to enable me to afford university                          0
# I have had to increase my hours at work to cover the higher cost of living             0
# ...

# %%
# remove null rows
data.dropna(how = 'all', inplace = True)

# %%
# numbers of rows for each column
data.nunique()
# Out:
# Award Level                                                                             6
# Dept                                                                                   23
# Fee Status                                                                              4
# Level of Study                                                                          7
# Campus                                                                                  5
# I know where to look for support in the university if I am struggling financially       6
# I am confident that I can create a personal monthly budget                              6
# My maintenance loan covers all my rent and bills                                        5
# I have/need a part time job to enable me to afford university                           8
# I have had to increase my hours at work to cover the higher cost of living              2
# ...

# %%
# unique variables in each column
data['Award Level'].unique()
# Out:
# array(['Engineering and Environment', 'Business and Law',
#        'Health and Life Sciences', 'Arts, Design and Social Sciences',
#        'unknown', 'Central Departments'], dtype=object)

# %%
data['Dept'].unique()
# Out:
# array(['Mechanical and Construction Engineering',
#        'Marketing, Operations and Systems',
#        'Leadership and Human Resource Management',
#        'Sport, Exercise and Rehabilitation',
#        'Computer and Information Sciences', 'Applied Sciences',
#        'Social Sciences', 'Geography and Environmental Sciences',
#        'unknown', 'Entrepreneurship, Innovation and Strategy',
#        'QA Pathway College',
#        'Mathematics, Physics and Electrical Engineering', 'Psychology',
#        'Architecture and Built Environment', 'Law', 'Design', 'Arts',
#        'Accounting and Financial Management',
#        'Health and Life Sciences Continous Professional Development',
#        'Nursing, Midwifery and Health',
#        'Social Work, Education and Community Wellbeing', 'Humanities',
#        'International Development'], dtype=object)

# %%
data['Fee Status'].unique()
# Out:
# array(['International', 'Unknown', 'Home', 'unknown'], dtype=object)

# %%
data['Level of Study'].unique()
# Out:
# array(['7', '5', '4', 'unknown', '6', '8', '3'], dtype=object)

# %%
data['Campus'].unique()
# Out:
# array(['City Campus', 'unknown', 'London Campus', 'Coach Lane',
#        'Amsterdam'], dtype=object)

# %%
# statiscal summary
data.describe()
# Out:
#              Award Level     Dept     Fee Status Level of Study       Campus  \
# count                511      511            511            511          511
# unique                 6       23              4              7            5
# top     Business and Law  unknown  International              7  City Campus
# freq                 128      104            224            203          202
#
#        I know where to look for support in the university if I am struggling financially   \
# count                                                 511
# unique                                                  6
# top                                                 Agree
# freq                                                  193
#
#        I am confident that I can create a personal monthly budget  \
# count                                                 511
# unique                                                  6
# top                                                 Agree
# ...

# %%
sns.displot(data['Award Level'])

# %%
sns.displot(data['Dept'])

# %%
sns.displot(data['Campus'])

# %%
sns.displot(data['Fee Status'])

# %%
sns.displot(data['Level of Study'])

# %%
import pandas as pd

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')

# Initialize the VADER sentiment intensity analyzer
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ikech\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
data2 = pd.read_csv("sent1.csv")
data2
# Out:
#                                                column1  \
# 0    balance enjoying non uni activities and stuff ...
# 1           rising of pounds in my country in Nigeria
# 2                          rising pound in my country
# 3     With the rising of pounds in my country Nigeria.
# 4         i cant work enough hours to pay my high rent
# ..                                                 ...
# 381                                      mental strain
# 382                                     no spare money
# 383                        emotionally and financially
# 384                     cant cope under cost of living
# 385                   cant afford rent and necessities
#
#                               column2  \
# 0                  balancing uni life
# 1                         assessment
# 2                   not getting a job
# 3     Not getting a job + assessment
# 4              student visas are hard
# ..                                ...
# ...

# %%
# Extract comments from the dataset
comments = data2['column1'].tolist()

# %%
# Perform sentiment analysis on each comment
sentiment_scores = []
for comment in comments:
    if pd.notnull(comment):  # Check if comment is not NaN
        sentiment_score = sia.polarity_scores(str(comment))
        sentiment_scores.append(sentiment_score)

# %%
# Display sentiment scores
for i, score in enumerate(sentiment_scores, 1):
    print(f"Comment {i} Sentiment: {score}")
# Out:
# Comment 1 Sentiment: {'neg': 0.0, 'neu': 0.524, 'pos': 0.476, 'compound': 0.8442}
# Comment 2 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 3 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 4 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 5 Sentiment: {'neg': 0.149, 'neu': 0.851, 'pos': 0.0, 'compound': -0.1027}
# Comment 6 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 7 Sentiment: {'neg': 0.279, 'neu': 0.721, 'pos': 0.0, 'compound': -0.4767}
# Comment 8 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 9 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 10 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 11 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 12 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ...

# %%
# Extract comments from the dataset
comments = data2['column2'].tolist()

# %%
# Perform sentiment analysis on each comment
sentiment_scores = []
for comment in comments:
    if pd.notnull(comment):  # Check if comment is not NaN
        sentiment_score = sia.polarity_scores(str(comment))
        sentiment_scores.append(sentiment_score)

# %%
# Display sentiment scores
for i, score in enumerate(sentiment_scores, 1):
    print(f"Comment {i} Sentiment: {score}")
# Out:
# Comment 1 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 2 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 3 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 4 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 5 Sentiment: {'neg': 0.318, 'neu': 0.682, 'pos': 0.0, 'compound': -0.1027}
# Comment 6 Sentiment: {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.1027}
# Comment 7 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 8 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 9 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 10 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 11 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 12 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ...

# %%
# Extract comments from the dataset
comments = data2['column3'].tolist()

# %%
# Perform sentiment analysis on each comment
sentiment_scores = []
for comment in comments:
    if pd.notnull(comment):  # Check if comment is not NaN
        sentiment_score = sia.polarity_scores(str(comment))
        sentiment_scores.append(sentiment_score)

# %%
# Display sentiment scores
for i, score in enumerate(sentiment_scores, 1):
    print(f"Comment {i} Sentiment: {score}")
# Out:
# Comment 1 Sentiment: {'neg': 0.0, 'neu': 0.43, 'pos': 0.57, 'compound': 0.6486}
# Comment 2 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 3 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 4 Sentiment: {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.3182}
# Comment 5 Sentiment: {'neg': 0.0, 'neu': 0.635, 'pos': 0.365, 'compound': 0.3182}
# Comment 6 Sentiment: {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.3182}
# Comment 7 Sentiment: {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.4215}
# Comment 8 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 9 Sentiment: {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.2732}
# Comment 10 Sentiment: {'neg': 0.23, 'neu': 0.574, 'pos': 0.197, 'compound': -0.1027}
# Comment 11 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Comment 12 Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ...

# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')

# Initialize the VADER sentiment intensity analyzer
sia = SentimentIntensityAnalyzer()

# Load the dataset (replace 'dataset.csv' with your dataset file)
data2 = pd.read_csv("sent1.csv")

# Extract comments from the dataset
comments = data2['column1'].tolist()

# Perform sentiment analysis on each comment
sentiment_scores = []
sentiment_labels = []
for comment in comments:
    if pd.notnull(comment):  # Check if comment is not NaN
        sentiment_score = sia.polarity_scores(str(comment))
        sentiment_scores.append(sentiment_score)
        
        # Interpret compound score
        compound_score = sentiment_score['compound']
        if compound_score >= 0.05:
            sentiment_labels.append('Positive')
        elif compound_score <= -0.05:
            sentiment_labels.append('Negative')
        else:
            sentiment_labels.append('Neutral')

# Add sentiment scores and labels to the dataframe
data2['Sentiment_Score'] = sentiment_scores
data2['Sentiment_Label'] = sentiment_labels

# Export the dataframe with sentiment scores to CSV
data2.to_csv('sentiment_scores.csv', index=False)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ikech\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')

# Initialize the VADER sentiment intensity analyzer
sia = SentimentIntensityAnalyzer()

# Load the dataset (replace 'dataset.csv' with your dataset file)
data2 = pd.read_csv("sent1.csv")

# Extract comments from the dataset
comments = data2['column2'].tolist()

# Perform sentiment analysis on each comment
sentiment_scores = []
sentiment_labels = []
for comment in comments:
    if pd.notnull(comment):  # Check if comment is not NaN
        sentiment_score = sia.polarity_scores(str(comment))
        sentiment_scores.append(sentiment_score)
        
        # Interpret compound score
        compound_score = sentiment_score['compound']
        if compound_score >= 0.05:
            sentiment_labels.append('Positive')
        elif compound_score <= -0.05:
            sentiment_labels.append('Negative')
        else:
            sentiment_labels.append('Neutral')

# Add sentiment scores and labels to the dataframe
data2['Sentiment_Score'] = sentiment_scores
data2['Sentiment_Label'] = sentiment_labels

# Export the dataframe with sentiment scores to CSV
data2.to_csv('sentiment2_scores.csv', index=False)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ikech\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')

# Initialize the VADER sentiment intensity analyzer
sia = SentimentIntensityAnalyzer()

# Load the dataset (replace 'dataset.csv' with your dataset file)
data2 = pd.read_csv("sent1.csv")

# Extract comments from the dataset
comments = data2['column3'].tolist()

# Perform sentiment analysis on each comment
sentiment_scores = []
sentiment_labels = []
for comment in comments:
    if pd.notnull(comment):  # Check if comment is not NaN
        sentiment_score = sia.polarity_scores(str(comment))
        sentiment_scores.append(sentiment_score)
        
        # Interpret compound score
        compound_score = sentiment_score['compound']
        if compound_score >= 0.05:
            sentiment_labels.append('Positive')
        elif compound_score <= -0.05:
            sentiment_labels.append('Negative')
        else:
            sentiment_labels.append('Neutral')

# Add sentiment scores and labels to the dataframe
data2['Sentiment_Score'] = sentiment_scores
data2['Sentiment_Label'] = sentiment_labels

# Export the dataframe with sentiment scores to CSV
data2.to_csv('sentiment3_scores.csv', index=False)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ikech\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset
data = pd.read_csv("northumbria.csv")

# %%
# cluster analysis using scatterplot
plt.figure(figsize=(8,6))
sns.scatterplot(data=data, x='Campus', y='Fee Status')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset
data = pd.read_csv("northumbria.csv")

# %%
# Example: Selecting two variables from the dataset
variable1 = data['Level of Study']
variable2 = data['Fee Status']

# %%
# Create a scatter plot
plt.scatter(variable1, variable2)
plt.title("Scatter Plot of Level of Study vs Fee Status")
plt.xlabel("Level of Study")
plt.ylabel("Fee Status")
plt.show()

# %%
def func_nb():
   data = pd.read_csv('northumbria.csv')
   df = DataFrame(data)
   df['Tag'] = df['Tag'].map(lambda x: re.sub(r'\W+', '_', x))
   return df

# %%
data
# Out:
#                      Award Level                                       Dept  \
# 0    Engineering and Environment    Mechanical and Construction Engineering
# 1               Business and Law          Marketing, Operations and Systems
# 2               Business and Law          Marketing, Operations and Systems
# 3               Business and Law          Marketing, Operations and Systems
# 4               Business and Law          Marketing, Operations and Systems
# ..                           ...                                        ...
# 506  Engineering and Environment          Computer and Information Sciences
# 507             Business and Law          Marketing, Operations and Systems
# 508             Business and Law  Entrepreneurship, Innovation and Strategy
# 509             Business and Law          Marketing, Operations and Systems
# 510          Central Departments                         QA Pathway College
#
#         Fee Status Level of Study         Campus  \
# ...

# %%
# unique variables in each column
data['Award Level'].unique()
# Out:
# array(['Engineering and Environment', 'Business and Law',
#        'Health and Life Sciences', 'Arts, Design and Social Sciences',
#        'unknown', 'Central Departments'], dtype=object)

# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('sent1.csv')
df
# Out:
#                                                column1  \
# 0    balance enjoying non uni activities and stuff ...
# 1           rising of pounds in my country in Nigeria
# 2                          rising pound in my country
# 3     With the rising of pounds in my country Nigeria.
# 4         i cant work enough hours to pay my high rent
# ..                                                 ...
# 381                                      mental strain
# 382                                     no spare money
# 383                        emotionally and financially
# 384                     cant cope under cost of living
# 385                   cant afford rent and necessities
#
#                               column2  \
# 0                  balancing uni life
# 1                         assessment
# 2                   not getting a job
# 3     Not getting a job + assessment
# 4              student visas are hard
# ..                                ...
# ...

# %%
# Assuming your text data is in a column named 'text', you can replace it with your actual column name
text_column = 'column1'

# Tokenization and Counting Word Frequency
word_counter = Counter()
for index, row in df.iterrows():
    words = row[text_column].split()  # Split text into words
    word_counter.update(words)  # Update counter with word frequency

# Identify Most Common Words
most_common_words = word_counter.most_common(10)  # Change 10 to the desired number of words

# Display Most Common Words
print("Most Common Words column1:")
for word, frequency in most_common_words:
    print(f"{word}: {frequency}")
# Out:
# Most Common Words column1:
# to: 117
# and: 116
# food: 83
# of: 81
# rent: 59
# cost: 46
# is: 45
# high: 42
# living: 39
# the: 36

# %%
# Assuming your text data is in a column named 'text', you can replace it with your actual column name
text_column = 'column2'

# Tokenization and Counting Word Frequency
word_counter = Counter()
for index, row in df.iterrows():
    words = row[text_column].split()  # Split text into words
    word_counter.update(words)  # Update counter with word frequency

# Identify Most Common Words
most_common_words = word_counter.most_common(10)  # Change 10 to the desired number of words

# Display Most Common Words
print("Most Common words column2:")
for word, frequency in most_common_words:
    print(f"{word}: {frequency}")
# Out:
# Most Common words column2:
# to: 91
# and: 79
# of: 58
# a: 47
# cost: 45
# the: 45
# accommodation: 38
# food: 34
# is: 34
# living: 28

# %%
# Assuming your text data is in a column named 'text', you can replace it with your actual column name
text_column = 'column3'

# Tokenization and Counting Word Frequency
word_counter = Counter()
for index, row in df.iterrows():
    words = row[text_column].split()  # Split text into words
    word_counter.update(words)  # Update counter with word frequency

# Identify Most Common Words
most_common_words = word_counter.most_common(10)  # Change 10 to the desired number of words

# Display Most Common Words
print("Most Common Words column3:")
for word, frequency in most_common_words:
    print(f"{word}: {frequency}")
# Out:
# Most Common Words column3:
# to: 82
# more: 63
# for: 58
# and: 55
# students: 51
# help: 47
# time: 45
# jobs: 43
# with: 39
# the: 36

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (replace 'your_dataset.csv' with the actual filename)
data = pd.read_csv('northumbria.csv')

# Select the two columns you want to analyze
column1 = 'Fee Status'  # Replace 'column_name_1' with the name of the first column
column2 = 'Campus'  # Replace 'column_name_2' with the name of the second column

# Method 2: Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data[column1], data[column2], alpha=0.5)
plt.title(f'Scatter Plot of {column1} vs {column2}')
plt.xlabel(column1)
plt.ylabel(column2)
plt.grid(True)
plt.show()
